# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
import json
import pandas as pd
import numpy as np

# %%
orignal_water_resource_data = "WaterResourcesChinaStatisticalYearbook.jpg"
orignal_water_supply_and_water_use_data = "WaterSupplyAndWaterUseChinaStatisticalYearbook.jpg"
china_water_risk_ecology_report = "china_water_risk_ecology_report.json"
water_resources = "water_resources.json"
water_resources_per_city_2020 = "water_resources_per_city_2020.json"
water_supply_and_water_use_per_city_2020 = "water_supply_and_water_use_per_city_2020.json"
water_supply_and_water_use = "water_supply_and_water_use.json"

# %%
def water_quality_bar_chart(years, worst, bad, good):
    fig, ax = plt.subplots()
    worst, bad, good = np.array(worst), np.array(bad), np.array(good)
    years = [x['year'] for x in water_quality_data]
    x = np.arange(len(years))  # the label locations
    width = 0.35  # the width of the bars
    rects1 = ax.bar(x, good+worst+bad, width, color='r', label="V+")
    rects2 = ax.bar(x, good+bad, width, color='y', label="IV-V")
    rects3 = ax.bar(x, good, width, color='g', label="I-III")
    ax.set_xticks(x, years)
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    return fig, ax

with open(china_water_risk_ecology_report, 'r') as f:
    water_quality_data = json.load(f)
sorted(water_quality_data, key= lambda x: x['year'])

key_lakes_and_reservoirs = [x['Key Lakes & Reservoirs'] for x in water_quality_data]
worst, bad, good = zip(*[(x['V+'], x['IV-V'], x['I-III']) for x in key_lakes_and_reservoirs])
fig, ax = water_quality_bar_chart(years, worst, bad, good)
fig.suptitle('Key Lakes & Reservoirs Water Quality')

main_river_basins = [x['Main River Basins'] for x in water_quality_data]
worst, bad, good = zip(*[(x['V+'], x['IV-V'], x['I-III']) for x in main_river_basins])
fig, ax = water_quality_bar_chart(years, worst, bad, good)
fig.suptitle('Main River Basins Water Quality')

water_quality_data

groundwater_and_shallow_grounwater = [x['Groundwater & shallow groundwater'] for x in water_quality_data]
def remap_data(x):
    if 'Very Bad' in x:
        x = {
            'V+': x['Very Bad'],
            'IV-V': x['Bad'],
            'I-III': x['Satisfactory'] + x['Good'] + x['Excellent'],
        }
    return x
        
groundwater_and_shallow_grounwater = [remap_data(x) for x in groundwater_and_shallow_grounwater]


worst, bad, good = zip(*[(x['V+'], x['IV-V'], x['I-III']) for x in groundwater_and_shallow_grounwater])
fig, ax = water_quality_bar_chart(years, worst, bad, good)
fig.suptitle('Groundwater and Shallow Groundwater Quality')
# Out:
# <img src="data:image/png;base64,..." width="945">
# <img src="data:image/png;base64,..." width="932">
# <img src="data:image/png;base64,..." width="937">
# Text(0.5, 0.98, 'Groundwater and Shallow Groundwater Quality')

# %%
with open(water_resources, 'r') as f:
    water_resources_data = json.load(f)
sorted(water_resources_data, key= lambda x: x['year'])

years = [x['year'] for x in water_resources_data]


per_capita_water_resources = [x['Per Capita Water Resources'] for x in water_resources_data]

fig, ax = plt.subplots()

ax.plot(years, per_capita_water_resources)

water_resources_data
# Out:
# <img src="data:image/png;base64,..." width="640">
# [{'year': 2000,
#   'Total Water Resources': 27700.8,
#   'Surface Water Resources': 26561.9,
#   'Ground Water Resources': 8501.9,
#   'Overlapped Measurement Between Surface Water and Groundwater': 7363.0,
#   'Per Capita Water Resources': 2193.9},
#  {'year': 2005,
#   'Total Water Resources': 28053.1,
#   'Surface Water Resources': 26982.4,
#   'Ground Water Resources': 8091.1,
#   'Overlapped Measurement Between Surface Water and Groundwater': 7020.4,
#   'Per Capita Water Resources': 2151.8},
#  {'year': 2006,
#   'Total Water Resources': 25330.1,
#   'Surface Water Resources': 24358.1,
#   'Ground Water Resources': 7642.9,
#   'Overlapped Measurement Between Surface Water and Groundwater': 6670.8,
#   'Per Capita Water Resources': 1932.1},
#  {'year': 2007,
#   'Total Water Resources': 25255.2,
#   'Surface Water Resources': 24242.5,
#   'Ground Water Resources': 7617.2,
#   'Overlapped Measurement Between Surface Water and Groundwater': 6604.5,
#   'Per Capita Water Resources': 1916.3},
#  {'year': 2008,
#   'Total Water Resources': 27434.3,
#   'Surface Water Resources': 26377.0,
#   'Ground Water Resources': 8122.0,
#   'Overlapped Measurement Between Surface Water and Groundwater': 7064.7,
#   'Per Capita Water Resources': 2071.1},
#  {'year': 2009,
#   'Total Water Resources': 24180.2,
#   'Surface Water Resources': 23125.2,
#   'Ground Water Resources': 7267.0,
#   'Overlapped Measurement Between Surface Water and Groundwater': 6212.1,
#   'Per Capita Water Resources': 1816.3},
#  {'year': 2010,
#   'Total Water Resources': 30906.4,
#   'Surface Water Resources': 29797.6,
#   'Ground Water Resources': 8417.0,
#   'Overlapped Measurement Between Surface Water and Groundwater': 7308.2,
#   'Per Capita Water Resources': 2310.4},
#  {'year': 2011,
#   'Total Water Resources': 23256.7,
#   'Surface Water Resources': 22213.6,
#   'Ground Water Resources': 7214.5,
#   'Overlapped Measurement Between Surface Water and Groundwater': 6171.4,
#   'Per Capita Water Resources': 1729.1},
#  {'year': 2012,
#   'Total Water Resources': 29528.8,
#   'Surface Water Resources': 28373.3,
#   'Ground Water Resources': 8296.4,
#   'Overlapped Measurement Between Surface Water and Groundwater': 7140.9,
#   'Per Capita Water Resources': 2180.5},
#  {'year': 2013,
#   'Total Water Resources': 27957.9,
#   'Surface Water Resources': 26839.5,
#   'Ground Water Resources': 8081.1,
#   'Overlapped Measurement Between Surface Water and Groundwater': 6962.7,
#   'Per Capita Water Resources': 2050.8},
#  {'year': 2014,
#   'Total Water Resources': 27266.9,
#   'Surface Water Resources': 26263.9,
#   'Ground Water Resources': 7745.0,
#   'Overlapped Measurement Between Surface Water and Groundwater': 6742.0,
#   'Per Capita Water Resources': 1987.6},
#  {'year': 2015,
#   'Total Water Resources': 27962.6,
#   'Surface Water Resources': 26900.8,
#   'Ground Water Resources': 7797.0,
#   'Overlapped Measurement Between Surface Water and Groundwater': 6735.2,
#   'Per Capita Water Resources': 2026.5},
#  {'year': 2016,
#   'Total Water Resources': 32466.4,
#   'Surface Water Resources': 31273.9,
#   'Ground Water Resources': 8854.8,
#   'Overlapped Measurement Between Surface Water and Groundwater': 76623.0,
#   'Per Capita Water Resources': 2339.4},
#  {'year': 2017,
#   'Total Water Resources': 28761.2,
#   'Surface Water Resources': 27746.3,
#   'Ground Water Resources': 8309.6,
#   'Overlapped Measurement Between Surface Water and Groundwater': 7294.7,
#   'Per Capita Water Resources': 2059.9},
#  {'year': 2018,
#   'Total Water Resources': 27462.5,
#   'Surface Water Resources': 26323.2,
#   'Ground Water Resources': 8246.5,
#   'Overlapped Measurement Between Surface Water and Groundwater': 7107.2,
#   'Per Capita Water Resources': 1957.7},
#  {'year': 2019,
#   'Total Water Resources': 29041.0,
#   'Surface Water Resources': 27993.3,
#   'Ground Water Resources': 8191.5,
#   'Overlapped Measurement Between Surface Water and Groundwater': 7143.8,
#   'Per Capita Water Resources': 2062.9},
#  {'year': 2020,
#   'Total Water Resources': 31605.2,
#   'Surface Water Resources': 30407.0,
#   'Ground Water Resources': 8553.5,
#   'Overlapped Measurement Between Surface Water and Groundwater': 7355.3,
#   'Per Capita Water Resources': 2239.8}]
